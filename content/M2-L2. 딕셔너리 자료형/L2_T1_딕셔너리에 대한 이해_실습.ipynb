# %% [markdown]
# # **Topic 1. 딕셔너리에 대한 이해_실습**

# %% [markdown]
# **1) 다음 값들로 구성된 딕셔너리 member를 선언하고 확인하세요.**
#
# - 이름: 홍길동
# - 나이: 25

# %% [markdown]
# [결과 예시]
#
# ~~~
# {'이름': '홍길동', '나이': 25}
# ~~~

# %%
member =
print(member)

# %% [markdown]
# **2) 다음 값들로 구성된 딕셔너리 member를 선언하고 확인하세요.**
#
# - 이름: 홍길동
# - 나이: 25
# - 전공: 경영학
# - 언어: ['C언어', '파이썬', '자바']

# %% [markdown]
# [결과 예시]
#
# ~~~
# {'이름': '홍길동', '나이': 25, '전공': '경영학', '언어': ['C언어', '파이썬', '자바']}
# ~~~

# %%
member =
print(member)

# %% [markdown]
# **3) 다음 구문을 실행하여 member 딕셔너리를 선언하고 이어지는 요구에 따라 코드를 작성하고 실행하세요.**

# %%
member = {'이름': '홍길동',
          '지역': '서울',
          '성별': '남자',
          '취미': ['등산', '영화감상', '파이썬코딩']}

# %% [markdown]
# ① 이름을 조회하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 홍길동
# ~~~

# %% [markdown]
# ② 취미를 조회하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# ['등산', '영화감상', '파이썬코딩']
# ~~~

# %% [markdown]
# ③ 취미 마지막 값을 조회하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 파이썬코딩
# ~~~
