# %% [markdown]
# # **Topic 4. 딕셔너리와 반복문_실습**

# %% [markdown]
# **1) 다음 딕셔너리 member의 키(key)와 값(value)을 [결과 예시]와 같은 형태로 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 이름: 홍길동
# 지역: 서울
# 성별: 남자
# 취미: ['등산', '영화감상', '파이썬코딩']
# ~~~

# %%
member = {'이름': '홍길동',
          '지역': '서울',
          '성별': '남자',
          '취미': ['등산', '영화감상', '파이썬코딩']}
for  ,  in  :
    print(f'{key}: {value}')

# %% [markdown]
# **2) 다음 딕셔너리 member의 키(key)와 값(value)을 [결과 예시]와 같은 형태로 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 1. 이름: 홍길동
# 2. 지역: 서울
# 3. 성별: 남자
# 4. 취미: ['등산', '영화감상', '파이썬코딩']
# ~~~

# %%
member = {'이름': '홍길동',
          '지역': '서울',
          '성별': '남자',
          '취미': ['등산', '영화감상', '파이썬코딩']}
i =
for  ,   in  :
    print(f'{i}. {key}: {value}')
    i += 1

# %% [markdown]
# **3) 다음 딕셔너리 score에서 점수가 90 이상인 과목을 리스트 score_good으로 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# ['수학', '과학', '영어', '사회']
# ~~~

# %%
score = {'국어': 85, '수학': 90, '과학': 100, '영어': 95, '역사': 80, '사회': 95}
score_good = [ ]
print(score_good)

# %% [markdown]
# **4) 다음 딕셔너리 score에서 점수가 90 미만인 과목과 점수를 딕셔너리 score_bad로 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# {'국어': 85, '역사': 80}
# ~~~

# %%
score = {'국어': 85, '수학': 90, '과학': 100, '영어': 95, '역사': 80, '사회': 95}
score_bad = { }
print(score_bad)
