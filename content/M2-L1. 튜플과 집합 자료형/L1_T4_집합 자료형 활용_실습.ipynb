# %% [markdown]
# # **Topic 4. 집합 자료형 활용_실습**

# %% [markdown]
# **1) 다음에 선언된 리스트 nums에서 중복된 요소를 제거하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# ~~~

# %%
nums = [1, 2, 2, 3, 4, 5, 5, 6, 7, 8, 8, 9]
nums =
print(nums)

# %% [markdown]
# **2) 다음에 선언된 두 리스트에서 중복된 요소를 뽑아 새로운 리스트 num3를 선언하고 확인하세요.**
#
# - 단, 리스트 num3를 오름차순으로 정럴하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# [2, 4, 9]
# ~~~

# %%
num1 = [1, 2, 4, 6, 8, 9]
num2 = [2, 3, 4, 5, 7, 9]
num3 =
num3.sort()
print(num3)

# %% [markdown]
# **3) 다음에 선언된 두 리스트를 결합해 새로운 리스트 num3를 선언하고 확인하세요.**
#
# - 단, 리스트 num3에 중복된 요소가 없어야 합니다.
# - 또한 num3를 오름차순으로 정렬하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# ~~~

# %%
num1 = [1, 2, 4, 6, 8, 9]
num2 = [2, 3, 4, 5, 7, 9]
num3 =
num3.sort()
print(num3)
