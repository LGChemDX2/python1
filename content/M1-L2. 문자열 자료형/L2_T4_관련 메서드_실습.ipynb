# %% [markdown]
# # **Topic 4. 관련 메서드_실습**

# %% [markdown]
# **1) 다음 변수에 대하여 이어지는 요구에 따라 대/소문자 변환을 수행하세요.**

# %%
life = 'LIFE is a JOURNEY'

# %% [markdown]
# ① 모두 대문자로 변환히여 출력

# %% [markdown]
# [결과 예시]
#
# ~~~
# LIFE IS A JOURNEY
# ~~~

# %%
print(life. )

# %% [markdown]
# ② 모두 소문자로 변환하여 출력

# %% [markdown]
# [결과 예시]
#
# ~~~
# life is a journey
# ~~~

# %%
print(life. )

# %% [markdown]
# ③ 단어 첫 글자는 대문자, 나머지는 모두 소문자로 변환하여 출력

# %% [markdown]
# [결과 예시]
#
# ~~~
# Life Is A Journey
# ~~~

# %%
print(life. )

# %% [markdown]
# ④ 문장 첫 글자만 대문자, 나머지는 모두 소문자로 변환하여 출력

# %% [markdown]
# [결과 예시]
#
# ~~~
# Life is a journey
# ~~~

# %%
print(life. )

# %% [markdown]
# **2) 변수 wow에 '나는 파이썬을 배우고 있다.'를 대입한 후, '배우고'를 '열심히 배우고'로 변경하여 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 나는 파이썬을 열심히 배우고 있다.
# ~~~

# %%
wow =
print(wow. )

# %% [markdown]
# **3) 변수 wow에 '나는 파이썬을 배우고 있다.'를 대입하고 공백을 기준으로 분할하여 리스트 형태로 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# ['나는', '파이썬을', '배우고', '있다.']
# ~~~

# %%
wow =
print(wow. )

# %% [markdown]
# **4) 리스트 animal = ['사자', '호랑이', '코끼리'] 일 때, 요소들 사이에 ','이 들어간 하나의 문자열 형태로 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 사자,호랑이,코끼리
# ~~~

# %%
animal = ['사자', '호랑이', '코끼리']
print( )

# %% [markdown]
# **5) 리스트 fruit = ['사과', '배', '복숭아'] 일 때, 요소들 사이에 '/'이 들어간 하나의 문자열 형태로 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 사과/배/복숭아
# ~~~

# %%
fruit = ['사과', '배', '복숭아']
print( )
