# %% [markdown]
# # **Topic 2. 고급 함수 만들기_실습**

# %% [markdown]
# **1) 다음 요구에 따라 함수 numbers()를 선언하고 사용해 보세요.**
#
# - 임의 개수의 숫자들을 입력받는 매개변수 nums를 사용하세요.
# - 매개변수로 입력받은 숫자들을 그대로 출력하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# (2, 4, 6, 8, 10)
# ~~~

# %%
# 함수 선언
def numbers( ):
    print( )

# %%
# 함수 사용
numbers(2, 4, 6, 8, 10)

# %% [markdown]
# **2) 다음 요구에 따라 함수 numbers()를 다시 선언하고 사용해 보세요.**
#
# - 임의 개수의 숫자들을 입력받는 매개변수 nums를 사용하세요.
# - 매개변수로 입력받은 숫자들을 하나씩 출력하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 2
# 4
# 6
# 8
# 10
# ~~~

# %%
# 함수 선언
def numbers( ):
    for i in  :
        print( )

# %%
# 함수 사용
numbers(2, 4, 6, 8, 10)

# %% [markdown]
# **3) 다음 요구에 따라 함수 average()를 선언하고 사용해 보세요.**
#
# - 임의 개수의 수를 입력받는 매개변수 nums을 사용하세요.
# - 매개변수로 입력받은 숫자들의 평균을 변수 avg에 저장하여 반환하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 6.0
# ~~~

# %%
# 함수 선언
def average( ):
    avg =   /
    return( )

# %%
# 함수 사용
a = average(2, 4, 6, 8, 10)
print(a)

# %% [markdown]
# **4) 다음 요구에 따라 함수 my_calculator()를 선언하고 사용해 보세요.**
#
# - 첫 번째, 두 번째 숫자를 입력받는 매개변수 n1, n2와 연산 부호를 입력받는 매개변수 operator를 사용하세요.
# - n1, n2 사이에 사칙연산자 부호에 해당하는 연산 수행 결과를 출력하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 11 * 2 = 22
# ~~~

# %%
# 함수 선언
def my_calculator( , , ):
    if operator == '+':
        result = n1 + n2
    elif operator == '-':
        result =
    elif operator == ' ':
        result =
    else:
        result = n1 / n2
    print(f'{ } { } { } = { }')

# %%
# 함수 사용
my_calculator(11, 2, '*')
