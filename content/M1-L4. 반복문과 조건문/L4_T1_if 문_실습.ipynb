# %% [markdown]
# # **Topic 1. if 문_실습**

# %% [markdown]
# **1) 변수 score에 임의의 점수를 대입하고, 점수가 90보다 크거나 같으면 'Pass'를 출력하세요.**

# %% [markdown]
# [결과 예시] score = 95인 경우
#
# ~~~
# Pass
# ~~~

# %%
score =

if  :
    print('Pass')

# %% [markdown]
# **2) 변수 age에 임의의 나이를 대입하고, 다음 조건에 맞게 출력하도록 아래 구문을 완성하세요.**
#
# - 10보다 작으면 '10대 미만'
# - 20보다 작으면 '10대'
# - 30보다 작으면 '20대'
# - 40보다 작으면 '30대'
# - 50보다 작으면 '40대'
# - 아니면 '50대 이상'

# %% [markdown]
# [결과 예시] age = 32인 경우
#
# ~~~
# 30대
# ~~~

# %%
age =

if age < 10:
    print('10대 미만')
elif age < 20:


else:
    print('50대 이상')

# %% [markdown]
# **3) 변수 score에 임의의 점수를 대입하고, 다음의 조건에 맞게 출력하도록 아래 구문을 완성하세요.**
#
# - 90 <= score 이면  'A'
# - 80 <= score < 90 이면 'B'
# - 70 <= score < 80 이면 'C'
# - 60 <= score < 70 이면 'D'
# - score < 60 이면 'F'

# %% [markdown]
# [결과 예시] score = 75인 경우
#
# ~~~
# C
# ~~~

# %%
score =

if (score >= 90):
    print('A')
elif (score >= 80):


else:
    print('F')

# %% [markdown]
# **4) 변수 num1에 임의의 숫자를 대입하고, 다음 조건에 맞게 출력하세요.**
#
# - 숫자가 11의 배수일 경우 '11의 배수입니다.'
# - 아니면, '11의 배수가 아닙니다.'

# %% [markdown]
# [결과 예시] num1 = 34인 경우
#
# ~~~
# 11의 배수가 아닙니다.
# ~~~

# %%
num1 =

if  :
    print( )
else:
    print( )
