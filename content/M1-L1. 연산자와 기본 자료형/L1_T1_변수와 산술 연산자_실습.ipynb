# %% [markdown]
# # **Topic 1. 변수와 산술 연산자_실습**

# %% [markdown]
# **1) 정수 80을 값으로 갖는 변수 score를 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 80
# ~~~

# %% [markdown]
# **2) 위에서 선언한 변수의 데이터 형식을 type() 함수를 사용해 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# int
# ~~~

# %% [markdown]
# **3) 임의의 정수를 값으로 갖는 변수 score1, score2를 선언하고 이들에 대한 사칙연산을 수행하세요.**

# %% [markdown]
# ① 변수 선언

# %%
score1 =
score2 =

# %% [markdown]
# ② 더하기

# %% [markdown]
# ③ 빼기

# %% [markdown]
# ④ 곱하기

# %% [markdown]
# ⑤ 나누기

# %% [markdown]
# **4) 국어, 수학, 영어 점수를 갖는 변수 세 개를 선언하고 합과 평균을 구하세요.**
#
# - 단, 어떤 과목인 지 알 수 있도록 의미있는 변수 이름을 사용하세요.

# %% [markdown]
# ① 변수 선언

# %% [markdown]
# ② 합

# %% [markdown]
# ③ 평균

# %% [markdown]
# **5) 다음 두 변수에 대하여 요구하는 연산을 수행하세요.**

# %%
num1 = 250
num2 = 4

# %% [markdown]
# ① num1을 num2로 나눌 때 몫을 구하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 62
# ~~~

# %% [markdown]
# ② num1을 num2로 나눌 때 나머지를 구하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 2
# ~~~

# %% [markdown]
# ③ num1을 num2 만큼 제곱한 수를 구하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 3906250000
# ~~~
