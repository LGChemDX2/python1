# %% [markdown]
# # **Topic 3. 인덱싱과 슬라이싱_실습**

# %% [markdown]
# **1) 1부터 10까지 정수를 갖는 리스트 n1을 선언하고, 첫 번째 요소와 마지막 요소를 각각 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 1
# 10
# ~~~

# %%
n1 = list( )
print(n1[ ])
print(n1[ ])

# %% [markdown]
# **2) 23, 3, 16, 45, 11을 요소로 갖는 리스트 n2를 선언하고 다음 내용을 수행하세요.**
#
# - 앞에서부터 첫 번째 요소와 네 번째 요소를 하나의 print() 함수로 확인
# - 뒤에서부터 첫 번째 요소와 세 번째 요소를 하나의 print() 함수로 확인

# %% [markdown]
# [결과 예시]
#
# ~~~
# 23 45
# 11 16
# ~~~

# %%
n2 = [23, 3, 16, 45, 11]
print(n2[ ], n2[ ])
print(n2[ ], n2[ ])

# %% [markdown]
# **3) 23, 3, 16, 45, 11을 요소로 갖는 리스트 n2를 선언하고, 두 번째부터 네 번째 요소까지 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [3, 16, 45]
# ~~~

# %%
n2 = [23, 3, 16, 45, 11]
print(n2[ ])

# %% [markdown]
# **4) 23, 3, 16, 45, 11을 요소로 갖는 리스트 n2를 선언하고, 세 번째부터 마지막 요소까지 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [16, 45, 11]
# ~~~

# %%
n2 = [23, 3, 16, 45, 11]
print(n2[ ])

# %% [markdown]
# **5) 23, 3, 16, 45, 11을 요소로 갖는 리스트 n2를 선언하고, 처음부터 세 번째 요소까지 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [23, 3, 16]
# ~~~

# %%
n2 = [23, 3, 16, 45, 11]
print(n2[ ])
