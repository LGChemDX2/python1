# %% [markdown]
# # **Topic 4. 리스트와 반복문_실습**

# %% [markdown]
# **1) 리스트 animal = ['사자', '코끼리', '하마', '기린', '얼룩말'] 일 때 반복문으로 요소를 하나씩 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 사자
# 코끼리
# 하마
# 기린
# 얼룩말
# ~~~

# %%
animal = ['사자', '코끼리', '하마', '기린', '얼룩말']

for a in animal:
    print(a)

# %% [markdown]
# **2) 리스트 movie = ['인어공주', '알라딘', '겨울왕국', '라푼젤'] 일 때 '라이언킹'를 추가하고, 요소를 하나씩 출력하세요.**
#
# - 힌트: append() 메서드로 값 하나를 추가합니다

# %% [markdown]
# [결과 예시]
#
# ~~~
# 인어공주
# 알라딘
# 겨울왕국
# 라푼젤
# 라이언킹
# ~~~

# %%
movie = ['인어공주', '알라딘', '겨울왕국', '라푼젤']
movie.append('라이언킹')
for m in movie:
    print(m)

# %% [markdown]
# **3) 빈 리스트 multiple7을 선언하고, 1부터 100까지의 값들 중 7의 배수를 multiple7에 저장한 후 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]
# ~~~

# %%
multiple7 = []

for n in range(1, 101):
    if n % 7 == 0:
        multiple7.append(n)
print(multiple7)

# %% [markdown]
# **4) 리스트 animal = ['사자', '코끼리', '하마', '기린', '얼룩말'] 일 때 반복문으로 요소를 하나씩 출력하세요.**
#
# - 단, 순번이 같이 출력되게 하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 0 - 사자
# 1 - 코끼리
# 2 - 하마
# 3 - 기린
# 4 - 얼룩말
# ~~~

# %%
animal = ['사자', '코끼리', '하마', '기린', '얼룩말']

for idx, val in enumerate(animal):
    print(idx, '-', val)

# %% [markdown]
# **5) 리스트 movie = ['인어공주', '알라딘', '겨울왕국', '라푼젤'] 일 때 반복문으로 요소를 하나씩 출력하세요.**
#
# - 단, 순번이 같이 출력되게 하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# 1 : 인어공주
# 2 : 알라딘
# 3 : 겨울왕국
# 4 : 라푼젤
# ~~~

# %%
movie = ['인어공주', '알라딘', '겨울왕국', '라푼젤']

for idx, m in enumerate(movie):
    print(idx + 1, ':', m)

# %% [markdown]
# **6) 1부터 100까지의 값들 중 7의 배수를 multiple7에 저장한 후 확인하세요.**
#
# - 단, 반복문 확장 구문을 사용하세요.

# %% [markdown]
# [결과 예시]
#
# ~~~
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]
# ~~~

# %%
multiple7 = [n for n in range(1, 101) if n % 7 == 0]
print(multiple7)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]
